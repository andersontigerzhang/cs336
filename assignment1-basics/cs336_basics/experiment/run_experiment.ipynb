# %%
# %cd ../..
# Out:
# /mnt/c/Users/andyz/stanford/cs336/Homeworks/assignment1-basics

# %%
# 2.5 BPE Training on TinyStories
# !uv run cs336_basics/experiment/train_bpe.py --vocab_size=10000 --data=data/TinyStoriesV2-GPT4-train.txt --output_vocab=output/tinystories_vocab.json --output_merges=output/tinystories_merges.txt
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.5 BPE Training on OpenWebText
# !uv run cs336_basics/experiment/train_bpe.py --vocab_size=32000 --data=data/owt-train.txt --output_vocab=output/owt_vocab.json --output_merges=output/owt_merges.txt
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# a1. TinyStories
# !uv run cs336_basics/experiment/tokenizer_experiments.py calc_compression_ratio --vocab=output/tinystories_vocab.json --merge=output/tinystories_merges.txt --input=data/TinyStoriesV2-GPT4-train.txt
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# a2. OpenWebText
# !uv run cs336_basics/experiment/tokenizer_experiments.py calc_compression_ratio --vocab=output/owt_vocab.json --merge=output/owt_merges.txt --input=data/owt_train.txt
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# b tokenize your OpenWebText sample with the TinyStories tokenizer
# !uv run cs336_basics/experiment/tokenizer_experiments.py calc_compression_ratio --vocab=output/tinystories_vocab.json --merge=output/tinystories_merges.txt --input=data/owt_train.txt
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# d1 encode the respective training and development datasets into a sequence of integer token IDs
# !uv run cs336_basics/experiment/tokenizer_experiments.py encode_file --vocab=output/tinystories_vocab.json --merge=output/tinystories_merges.txt --input=data/TinyStoriesV2-GPT4-train.txt --output=output/tinystories_train.bin
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# d2 encode the respective training and development datasets into a sequence of integer token IDs
# !uv run cs336_basics/experiment/tokenizer_experiments.py encode_file --vocab=output/tinystories_vocab.json --merge=output/tinystories_merges.txt --input=data/TinyStoriesV2-GPT4-valid.txt --output=output/tinystories_valid.bin
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# d3 encode the respective training and development datasets into a sequence of integer token IDs
# !uv run cs336_basics/experiment/tokenizer_experiments.py encode_file --vocab=output/owt_vocab.json --merge=output/owt_merges.txt --input=data/owt_valid.txt --output=output/owt_valid.bin
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...

# %%
# 2.7 Experiments with tokenizers
# d4 encode the respective training and development datasets into a sequence of integer token IDs
# !uv run cs336_basics/experiment/tokenizer_experiments.py encode_file --vocab=output/owt_vocab.json --merge=output/owt_merges.txt --input=data/owt_train.txt --output=output/owt_train.bin
# Out:
# INFO:root:{'--data': 'data/TinyStoriesV2-GPT4-valid.txt',
#  '--output_merges': 'output/tinystories_merges.txt',
#  '--output_vocab': 'output/tinystories_vocab.json',
#  '--vocab_size': '10000'}
# INFO:root:Processing 21 chunks with 4 workers...
